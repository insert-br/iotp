# %%
# %autosave 60
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib 
import matplotlib.font_manager
import scipy.stats
# Out:
# Autosaving every 60 seconds

# %%
barplot = True
lang = 'ptbr'

confidence = 95
results_dir = 'results'
# switch_json = results_dir + '/switch_dataset.json'
iotp_json = results_dir + '/iotp_factorial.json'
iotp_csv = results_dir + '/iotp_factorial.csv'
iotp_excel = results_dir + '/iotp_factorial.xlsx'

factors_map = {    
    'IoTP DT 10': -1,
    'IoTP DT 50': 1,    
    '10': -1,
    '50': 1,    
    '0.0': -1,
    '0.1': 1
}
nm_map = {
#     'aggregation_strategy': u'Aggregation Strategy',
    'aggregation_strategy': u'A',
    'avg_delay': u'Average Aggregation Delay (ms)',    
    'avg_voltage': u'IoT Device Battery (V)',    
    'data_per_pkt': u'Data per Packet',
#     'devices': u'IoT Devices',
    'devices': u'B',
    'goodput': u'Goodput (B/s)',
    'gt': u'G/T (%)',
    'pkt_loss': u'Packet Loss (%)', 
    'pkt_recv': u'Received Packets',
    'pkt_send': u'Sent Packets',
    'pps_recv': u'Gateway Received Packets (pps)', 
    'pps_send': u'Router Received Packet (pps)', 
    'sample_int': u'Sampling Interval (s)', 
#     'sync_flag': u'Sync Flag Send Interval (s)',
    'sync_flag': u'C',
    'throughput': u'Throughput (B/s)',
    'topology': u'Topology'
}
nm_keys = nm_map.keys()
nm_keys.sort()

factors_arr  = [ nm_map['aggregation_strategy'], nm_map['devices'], nm_map['sync_flag'] ]
measures_arr = [ nm_map['throughput'], nm_map['goodput'], nm_map['gt'], nm_map['avg_delay'], nm_map['pkt_recv'], nm_map['pkt_send'] ]

df = pd.concat([
#     pd.read_json(switch_json, orient='records', typ='frame'), 
    pd.read_json(iotp_json, orient='records', typ='frame')
])
# df = df[ (df['data_per_pkt'] == 10) ]
# if barplot:
#     df = df[ (df['pps_tcpreplay'] == barplot_pps) ]

df.set_axis(map(lambda x: nm_map[x], nm_keys), axis=1, inplace=True)
# df
# df_not_l2 = df[df[nm_map['aggregation_strategy']] != "L2 Switch"]
# df_l2_iotp10 = df[(df[nm_map['aggregation_strategy']] == "L2 Switch") | (df[nm_map['aggregation_strategy']] == "IOTP DT 10")]

# %%
# kurtosis
# < 0    The peak is lower and broader, lack of outliers
# > 0    Peak is higher and sharper, profusion of outliers
# skewness
# < |0.5|           fairly simmetrical
# [|0.5|, |1.0|]    moderate skew
# > |1.0|           high skew
def calculate_descriptive_stat(df):
    kur_skew = pd.concat([df.kurtosis() - 3, df.skew()], axis=1, keys=[u'Kurtosis Normalizado',u'Skewness']).transpose()
    stat = df.describe()
    conf_var = scipy.stats.t.ppf((1 + confidence/100.) / 2., stat.loc['count']-1) * stat.loc['std']
    conf_int = pd.concat([stat.loc['mean']-conf_var, stat.loc['mean']+conf_var], axis=1, keys=[u'Intervalo de Confiança - Limite Inferior',u'Intervalo de Confiança - Limite Superior']).transpose()
    stat.set_axis([u'Amostragem', u'Média', u'Desvio Padrão', u'Mínimo', u'1º Quartil', u'2º Quartil', u'3º Quartil', u'Máximo'], axis=0, inplace=True)
    stat = pd.concat([stat, conf_int])
    stat = pd.concat([stat, kur_skew])
    return stat

# calculate_descriptive_stat(df.loc[df[nm_map['aggregation_strategy']] == u'L2 Switch'])

# %%
dpi = 350
capsize = 4.5

# style (defines grid style): darkgrid, whitegrid, dark, white, ticks
# palette (defines the color pallete): deep, muted, bright, pastel, dark, colorblind
# font: "serif", "sans-serif"
sns.set(
    context="notebook", style="whitegrid", palette="muted", 
    font=u"arial,Verdana,Noto Sans,Times New Roman,serif,sans-serif", 
    font_scale=1.15, 
    rc={"lines.linewidth": 1.25}
)

def get_matplotlib_available_fonts():
    matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

def save_plot(filename, sns_axis):            
    # make room for the xlabel in the saved figure
    plt.gcf().subplots_adjust(left=0.17, bottom=0.17)
    # save files    
    sns_axis.figure.savefig('%s/%s.png' %(results_dir, filename), format='png', dpi=dpi, bbox_inches = 'tight')

def set_scale(ax, scale, scale_lim):    
    if (scale[0] == 'log'):
        ax.set_xscale('log')
    if (scale[1] == 'log'):
        ax.set_yscale('log')    
    if scale_lim[0]:
        ax.set(xlim=scale_lim[0])
    if scale_lim[1]:
        ax.set(ylim=scale_lim[1])        

def show_lineplot(df, filename, x, y, category, ax=None, scale=[None, None], scale_lim=[None, None], size=(6,6)):
    if size:
        plt.figure(figsize=size)
    ax = sns.lineplot(x=nm_map[x], y=nm_map[y], ax=ax, legend="brief",             
            hue=nm_map[category], style=nm_map[category],
            markers=True, dashes=False, 
            err_style='bars', estimator='mean', ci=confidence, err_kws={'capsize':capsize},
            data=df)
    set_scale(ax, scale=scale, scale_lim=scale_lim)
    save_plot(filename, ax)
    return ax
    
def show_barplot(df, filename, x, y, ax=None, scale=[None, None], scale_lim=[None, None], size=(6,6)):
    if size:
        plt.figure(figsize=size)
    ax = sns.barplot(x=nm_map[x], y=nm_map[y], ax=ax, 
                     estimator=np.mean, ci=confidence, capsize=capsize/18.0,
                     data=df)
    set_scale(ax, scale=scale, scale_lim=scale_lim)
    save_plot(filename, ax)
    return ax

def show_pareto(filename, y, title=None, xlabel=None, ylabel=None, ylabel2=None, colors=('C0','C1'), scale=[None, None], scale_lim=[None, None], size=(6,6)):
    if size:
        plt.figure(figsize=size)
        
    y.sort_values(ascending=False, inplace=True)
    sum_y = y.sum()
    fig, ax = plt.subplots()
    ax.bar(y.index, y, color=colors[0])
    if ylabel:
        ax.set_ylabel(ylabel) 
    ax2 = ax.twinx()
    ax2.plot(y.index, y.cumsum() / sum_y * 100.0, color=colors[1], marker="D", ms=7)
#     ax.yaxis.set_major_formatter(matplotlib.ticker.PercentFormatter())
    ax2.yaxis.set_major_formatter(matplotlib.ticker.PercentFormatter())
    ax.yaxis.set_label_position("left")
    ax.tick_params(axis="y", colors=colors[0])    
    ax2.tick_params(axis="y", colors=colors[1])
    if title:
        ax.set_title(title)
    if xlabel:
        ax.set_xlabel(xlabel)
    if ylabel2:
        ax2.set_ylabel(ylabel2)
    set_scale(ax, scale=scale, scale_lim=scale_lim)               
    plt.show()
    save_plot(filename, ax)
    return ax

# %%
# create combined factors (interference)
def compute_interference_factor(df_new, factorA, factorB):
    new_factor_name = factorA + factorB 
    new_factor = (df_new[factorA] * df_new[factorB]).to_frame()
    new_factor.set_axis([new_factor_name], axis=1, inplace=True)
    factors_arr.append(new_factor_name)
    return pd.concat([df_new, new_factor], axis=1)

def compute_interference_factor3(df_new, factorA, factorB, factorC):
    new_factor_name = factorA + factorB + factorC
    new_factor = (df_new[factorA] * df_new[factorB] * df_new[factorC]).to_frame()
    new_factor.set_axis([new_factor_name], axis=1, inplace=True)
    factors_arr.append(new_factor_name)
    return pd.concat([df_new, new_factor], axis=1)
df
# Out:
#               A  Average Aggregation Delay (ms)  IoT Device Battery (V)  \
# 0    IoTP DT 10                      162.719097                2.647007
# 1    IoTP DT 10                      166.100589                2.647212
# 2    IoTP DT 10                      166.828466                2.646607
# 3    IoTP DT 10                      166.507169                2.646602
# 4    IoTP DT 10                      166.800581                2.646603
# 5    IoTP DT 10                      159.470886                2.646607
# 6    IoTP DT 10                      170.661212                2.646202
# 7    IoTP DT 10                      166.530627                2.646807
# 8    IoTP DT 10                      166.962640                2.646402
# 9    IoTP DT 10                      169.669758                2.647612
# 10   IoTP DT 10                      169.414267                2.647007
# 11   IoTP DT 10                      165.206911                2.646807
# 12   IoTP DT 10                      170.687072                2.646807
# 13   IoTP DT 10                      168.785250                2.646807
# 14   IoTP DT 10                      168.917483                2.646602
# 15   IoTP DT 10                      169.713907                2.646402
# 16   IoTP DT 10                      170.121208                2.646603
# 17   IoTP DT 10                      167.037877                2.647412
# 18   IoTP DT 10                      169.570682                2.647012
# 19   IoTP DT 10                      169.469424                2.646602
# 20   IoTP DT 10                       88.167895                2.625920
# 21   IoTP DT 10                       87.749897                2.529557
# 22   IoTP DT 10                       91.035083                2.526378
# 23   IoTP DT 10                       88.154715                2.624980
# 24   IoTP DT 10                       91.861267                2.627008
# 25   IoTP DT 10                       88.782800                2.652039
# 26   IoTP DT 10                       89.148056                2.600312
# 27   IoTP DT 10                       85.975223                2.579563
# 28   IoTP DT 10                       85.708272                2.654385
# 29   IoTP DT 10                       88.384609                2.626284
# ..          ...                             ...                     ...
# 130  IoTP DT 50                      262.699094                2.486546
# 131  IoTP DT 50                      431.804184                2.486371
# 132  IoTP DT 50                      314.415963                2.488570
# 133  IoTP DT 50                      271.875319                2.490126
# 134  IoTP DT 50                      235.444658                2.485435
# 135  IoTP DT 50                      233.648725                2.489116
# 136  IoTP DT 50                      275.278882                2.486505
# 137  IoTP DT 50                      446.178119                2.485043
# 138  IoTP DT 50                      257.058468                2.490002
# 139  IoTP DT 50                      358.842561                2.487970
# 140  IoTP DT 50                      299.150329                2.512281
# 141  IoTP DT 50                      192.460065                2.497311
# 142  IoTP DT 50                      251.052995                2.502877
# 143  IoTP DT 50                      157.032764                2.496509
# 144  IoTP DT 50                      222.362668                2.498712
# 145  IoTP DT 50                      169.235914                2.502446
# 146  IoTP DT 50                      134.531889                2.491660
# 147  IoTP DT 50                      191.265191                2.491138
# 148  IoTP DT 50                      196.484676                2.456067
# 151               50  50         5411.2  90.319135        -1.258885
# 152               50  50         6694.4  90.778911        -1.111416
# 153               50  50         5364.0  90.930666        -1.061079
# 154               50  50         7400.8  90.631659        -1.162791
# 155               50  50         8328.0  90.100617        -1.399276
# 156               50  50         6992.8  90.812046        -1.113996
# 157               50  50         9113.6  90.470140        -1.256721
# 158               50  50         7462.4  90.454430        -1.226798
# 159               50  50         7876.8  90.597288        -1.185892
#
#      Received Packets  Sent Packets  Gateway Received Packets (pps)  \
# 0                 236          2384                            23.6
# 1                 236          2384                            23.6
# 2                 236          2384                            23.6
# 3                 236          2384                            23.6
# 4                 236          2384                            23.6
# 5                 236          2384                            23.6
# 6                 236          2384                            23.6
# 7                 236          2384                            23.6
# 8                 236          2384                            23.6
# 9                 236          2384                            23.6
# 10                236          2384                            23.6
# 11                236          2384                            23.6
# 12                236          2384                            23.6
# 13                236          2384                            23.6
# 14                236          2384                            23.6
# 15                236          2384                            23.6
# 16                236          2384                            23.6
# 17                236          2384                            23.6
# 18                236          2384                            23.6
# 19                236          2384                            23.6
# 20                408          2788                            40.8
# 21                427          2788                            42.7
# 22                421          2788                            42.1
# 23                407          2788                            40.7
# 24                412          2788                            41.2
# 25                404          2788                            40.4
# 26                413          2788                            41.3
# 27                430          2788                            43.0
# 28                412          2788                            41.2
# 29                412          2788                            41.2
# ..                ...           ...                             ...
# 130               192          9728                            19.2
# 131               125          6338                            12.5
# 132               191          9653                            19.1
# 133               185          9354                            18.5
# 134               219         11040                            21.9
# 135               222         11215                            22.2
# 136               187          9410                            18.7
# 137               118          6010                            11.8
# 138               203         10268                            20.3
# 139               230         11600                            23.0
# 140               173          5662                            17.3
# 141               293          9454                            29.3
# 142               203          6609                            20.3
# 143               322         10472                            32.2
# 144               247          8157                            24.7
# 145               327         10066                            32.7
# 146               334         10794                            33.4
# 147               256          8335                            25.6
# 148               290          9221                            29.0
# 149               273          8135                            27.3
# 150               204          6635                            20.4
# 151               232          7119                            23.2
# 152               272          8742                            27.2
# 153               214          6991                            21.4
# 154               306          9675                            30.6
# 155               366         10767                            36.6
# 156               283          9088                            28.3
# 157               384         11791                            38.4
# 158               315          9762                            31.5
# 159               327         10264                            32.7
#
#      Router Received Packet (pps)  Sampling Interval (s)    C  \
# 0                           238.4                     10  0.0
# 1                           238.4                     10  0.0
# 2                           238.4                     10  0.0
# 3                           238.4                     10  0.0
# 4                           238.4                     10  0.0
# 5                           238.4                     10  0.0
# 6                           238.4                     10  0.0
# 7                           238.4                     10  0.0
# 8                           238.4                     10  0.0
# 9                           238.4                     10  0.0
# 10                          238.4                     10  0.0
# 11                          238.4                     10  0.0
# 12                          238.4                     10  0.0
# 13                          238.4                     10  0.0
# 14                          238.4                     10  0.0
# 15                          238.4                     10  0.0
# 16                          238.4                     10  0.0
# 17                          238.4                     10  0.0
# 18                          238.4                     10  0.0
# 19                          238.4                     10  0.0
# 20                          278.8                     10  0.1
# 21                          278.8                     10  0.1
# 22                          278.8                     10  0.1
# 23                          278.8                     10  0.1
# 24                          278.8                     10  0.1
# 25                          278.8                     10  0.1
# 26                          278.8                     10  0.1
# 27                          278.8                     10  0.1
# 28                          278.8                     10  0.1
# 29                          278.8                     10  0.1
# ..                            ...                    ...  ...
# 130                         972.8                     10  0.0
# 131                         633.8                     10  0.0
# 132                         965.3                     10  0.0
# 133                         935.4                     10  0.0
# 134                        1104.0                     10  0.0
# 135                        1121.5                     10  0.0
# 136                         941.0                     10  0.0
# 137                         601.0                     10  0.0
# 138                        1026.8                     10  0.0
# 139                        1160.0                     10  0.0
# 140                         566.2                     10  0.1
# 141                         945.4                     10  0.1
# 142                         660.9                     10  0.1
# 143                        1047.2                     10  0.1
# 144                         815.7                     10  0.1
# 145                        1006.6                     10  0.1
# 146                        1079.4                     10  0.1
# 147                         833.5                     10  0.1
# 148                         922.1                     10  0.1
# 149                         813.5                     10  0.1
# 150                         663.5                     10  0.1
# 151                         711.9                     10  0.1
# 152                         874.2                     10  0.1
# 153                         699.1                     10  0.1
# 154                         967.5                     10  0.1
# 155                        1076.7                     10  0.1
# 156                         908.8                     10  0.1
# 157                        1179.1                     10  0.1
# 158                         976.2                     10  0.1
# 159                        1026.4                     10  0.1
#
#      Throughput (B/s)                                           Topology
# 0              2478.0                                        wwwwwwwwwwc
# 1              2478.0                                        wwwwwwwwwwc
# 2              2478.0                                        wwwwwwwwwwc
# 3              2478.0                                        wwwwwwwwwwc
# 4              2478.0                                        wwwwwwwwwwc
# 5              2478.0                                        wwwwwwwwwwc
# 6              2478.0                                        wwwwwwwwwwc
# 7              2478.0                                        wwwwwwwwwwc
# 8              2478.0                                        wwwwwwwwwwc
# 9              2478.0                                        wwwwwwwwwwc
# 10             2478.0                                        wwwwwwwwwwc
# 11             2478.0                                        wwwwwwwwwwc
# 12             2478.0                                        wwwwwwwwwwc
# 13             2478.0                                        wwwwwwwwwwc
# 14             2478.0                                        wwwwwwwwwwc
# 15             2478.0                                        wwwwwwwwwwc
# 16             2478.0                                        wwwwwwwwwwc
# 17             2478.0                                        wwwwwwwwwwc
# 18             2478.0                                        wwwwwwwwwwc
# 19             2478.0                                        wwwwwwwwwwc
# 20             2904.8                                        wwwwwwwwwwc
# 21             2961.9                                        wwwwwwwwwwc
# 22             2950.1                                        wwwwwwwwwwc
# 23             2918.3                                        wwwwwwwwwwc
# 24             2934.0                                        wwwwwwwwwwc
# 25             2901.2                                        wwwwwwwwwwc
# 26             2926.9                                        wwwwwwwwwwc
# 27             2975.8                                        wwwwwwwwwwc
# 28             2921.2                                        wwwwwwwwwwc
# 29             2927.6                                        wwwwwwwwwwc
# ..                ...                                                ...
# 130            8160.0  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 131            5312.5  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 132            8117.5  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 133            7862.5  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 134            9307.5  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 135            9435.0  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 136            7947.5  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 137            5015.0  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 138            8627.5  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 139            9775.0  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 140            4706.9  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 141            7953.3  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 142            5556.3  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 143            8835.4  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 144            6871.9  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 145            8627.1  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 146            9160.6  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 147            7016.0  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 148            7899.4  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 149            6986.5  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 150            5582.8  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 151            5991.2  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 152            7374.4  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 153            5899.0  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 154            8165.8  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 155            9243.0  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 156            7700.3  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 157           10073.6  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 158            8249.9  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 159            8694.3  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
#
# [160 rows x 16 columns]

# %%
# map factor levels to numbers
df[factors_arr] = df[factors_arr].applymap(lambda x: factors_map[str(x)])
df
# Out:
#      A  Average Aggregation Delay (ms)  IoT Device Battery (V)  \
# 0   -1                      162.719097                2.647007
# 1   -1                      166.100589                2.647212
# 2   -1                      166.828466                2.646607
# 3   -1                      166.507169                2.646602
# 4   -1                      166.800581                2.646603
# 5   -1                      159.470886                2.646607
# 6   -1                      170.661212                2.646202
# 7   -1                      166.530627                2.646807
# 8   -1                      166.962640                2.646402
# 9   -1                      169.669758                2.647612
# 10  -1                      169.414267                2.647007
# 11  -1                      165.206911                2.646807
# 12  -1                      170.687072                2.646807
# 13  -1                      168.785250                2.646807
# 14  -1                      168.917483                2.646602
# 15  -1                      169.713907                2.646402
# 16  -1                      170.121208                2.646603
# 17  -1                      167.037877                2.647412
# 18  -1                      169.570682                2.647012
# 19  -1                      169.469424                2.646602
# 20  -1                       88.167895                2.625920
# 21  -1                       87.749897                2.529557
# 22  -1                       91.035083                2.526378
# 23  -1                       88.154715                2.624980
# 24  -1                       91.861267                2.627008
# 25  -1                       88.782800                2.652039
# 26  -1                       89.148056                2.600312
# 27  -1                       85.975223                2.579563
# 28  -1                       85.708272                2.654385
# 29  -1                       88.384609                2.626284
# ..  ..                             ...                     ...
# 130  1                      262.699094                2.486546
# 131  1                      431.804184                2.486371
# 132  1                      314.415963                2.488570
# 133  1                      271.875319                2.490126
# 134  1                      235.444658                2.485435
# 135  1                      233.648725                2.489116
# 136  1                      275.278882                2.486505
# 137  1                      446.178119                2.485043
# 138  1                      257.058468                2.490002
# 139  1                      358.842561                2.487970
# 140  1                      299.150329                2.512281
# 141  1                      192.460065                2.497311
# 142  1                      251.052995                2.502877
# 143  1                      157.032764                2.496509
# 144  1                      222.362668                2.498712
# 145  1                      169.235914                2.502446
# 146  1                      134.531889                2.491660
# 147  1                      191.265191                2.491138
# 148  1                      196.484676                2.456067
# 149  1                      198.447828                2.501607
# 150  1                      242.168284                2.493774
# 151  1                      215.926073                2.504310
# 152  1                      183.766842                2.451785
# 153  1                      237.992738                2.447236
# 154  1                      159.757621                2.499846
# 155  1                      753.671221                2.067811
# 156  1                      223.954876                2.497659
# 157  1                     1069.298823                2.055815
# 158  1                      161.073997                2.465168
# 159  1                      162.628318                2.458515
#
#      Data per Packet  B  Goodput (B/s)    G/T (%)  Packet Loss (%)  \
# 0                 10 -1         1888.0  76.190476         0.100671
# 1                 10 -1         1888.0  76.190476         0.100671
# 2                 10 -1         1888.0  76.190476         0.100671
# 3                 10 -1         1888.0  76.190476         0.100671
# 4                 10 -1         1888.0  76.190476         0.100671
# 5                 10 -1         1888.0  76.190476         0.100671
# 6                 10 -1         1888.0  76.190476         0.100671
# 7                 10 -1         1888.0  76.190476         0.100671
# 8                 10 -1         1888.0  76.190476         0.100671
# 9                 10 -1         1888.0  76.190476         0.100671
# 10                10 -1         1888.0  76.190476         0.100671
# 22                421          2788                            42.1
# 23                407          2788                            40.7
# 24                412          2788                            41.2
# 25                404          2788                            40.4
# 26                413          2788                            41.3
# 27                430          2788                            43.0
# 28                412          2788                            41.2
# 29                412          2788                            41.2
# ..                ...           ...                             ...
# 130               192          9728                            19.2
# 131               125          6338                            12.5
# 132               191          9653                            19.1
# 133               185          9354                            18.5
# 134               219         11040                            21.9
# 135               222         11215                            22.2
# 136               187          9410                            18.7
# 137               118          6010                            11.8
# 138               203         10268                            20.3
# 139               230         11600                            23.0
# 140               173          5662                            17.3
# 141               293          9454                            29.3
# 142               203          6609                            20.3
# 143               322         10472                            32.2
# 144               247          8157                            24.7
# 145               327         10066                            32.7
# 146               334         10794                            33.4
# 147               256          8335                            25.6
# 148               290          9221                            29.0
# 149               273          8135                            27.3
# 150               204          6635                            20.4
# 151               232          7119                            23.2
# 152               272          8742                            27.2
# 153               214          6991                            21.4
# 154               306          9675                            30.6
# 155               366         10767                            36.6
# 156               283          9088                            28.3
# 157               384         11791                            38.4
# 158               315          9762                            31.5
# 159               327         10264                            32.7
#
#      Router Received Packet (pps)  Sampling Interval (s)  C  Throughput (B/s)  \
# 0                           238.4                     10 -1            2478.0
# 1                           238.4                     10 -1            2478.0
# 2                           238.4                     10 -1            2478.0
# 3                           238.4                     10 -1            2478.0
# 4                           238.4                     10 -1            2478.0
# 5                           238.4                     10 -1            2478.0
# 6                           238.4                     10 -1            2478.0
# 7                           238.4                     10 -1            2478.0
# 8                           238.4                     10 -1            2478.0
# 9                           238.4                     10 -1            2478.0
# 10                          238.4                     10 -1            2478.0
# 11                          238.4                     10 -1            2478.0
# 12                          238.4                     10 -1            2478.0
# 13                          238.4                     10 -1            2478.0
# 14                          238.4                     10 -1            2478.0
# 15                          238.4                     10 -1            2478.0
# 16                          238.4                     10 -1            2478.0
# 17                          238.4                     10 -1            2478.0
# 18                          238.4                     10 -1            2478.0
# 19                          238.4                     10 -1            2478.0
# 20                          278.8                     10  1            2904.8
# 21                          278.8                     10  1            2961.9
# 22                          278.8                     10  1            2950.1
# 23                          278.8                     10  1            2918.3
# 24                          278.8                     10  1            2934.0
# 25                          278.8                     10  1            2901.2
# 26                          278.8                     10  1            2926.9
# 27                          278.8                     10  1            2975.8
# 28                          278.8                     10  1            2921.2
# 29                          278.8                     10  1            2927.6
# ..                            ...                    ... ..               ...
# 130                         972.8                     10 -1            8160.0
# 131                         633.8                     10 -1            5312.5
# 132                         965.3                     10 -1            8117.5
# 133                         935.4                     10 -1            7862.5
# 134                        1104.0                     10 -1            9307.5
# 135                        1121.5                     10 -1            9435.0
# 136                         941.0                     10 -1            7947.5
# 137                         601.0                     10 -1            5015.0
# 138                        1026.8                     10 -1            8627.5
# 139                        1160.0                     10 -1            9775.0
# 140                         566.2                     10  1            4706.9
# 141                         945.4                     10  1            7953.3
# 142                         660.9                     10  1            5556.3
# 143                        1047.2                     10  1            8835.4
# 144                         815.7                     10  1            6871.9
# 145                        1006.6                     10  1            8627.1
# 146                        1079.4                     10  1            9160.6
# 147                         833.5                     10  1            7016.0
# 148                         922.1                     10  1            7899.4
# 149                         813.5                     10  1            6986.5
# 150                         663.5                     10  1            5582.8
# 151                         711.9                     10  1            5991.2
# 152                         874.2                     10  1            7374.4
# 153                         699.1                     10  1            5899.0
# 154                         967.5                     10  1            8165.8
# 155                        1076.7                     10  1            9243.0
# 156                         908.8                     10  1            7700.3
# 157                        1179.1                     10  1           10073.6
# 158                         976.2                     10  1            8249.9
# 159                        1026.4                     10  1            8694.3
#
#                                               Topology
# 0                                          wwwwwwwwwwc
# 1                                          wwwwwwwwwwc
# 2                                          wwwwwwwwwwc
# 3                                          wwwwwwwwwwc
# 4                                          wwwwwwwwwwc
# 5                                          wwwwwwwwwwc
# 6                                          wwwwwwwwwwc
# 7                                          wwwwwwwwwwc
# 8                                          wwwwwwwwwwc
# 9                                          wwwwwwwwwwc
# 10                                         wwwwwwwwwwc
# 11                                         wwwwwwwwwwc
# 12                                         wwwwwwwwwwc
# 13                                         wwwwwwwwwwc
# 14                                         wwwwwwwwwwc
# 15                                         wwwwwwwwwwc
# 16                                         wwwwwwwwwwc
# 17                                         wwwwwwwwwwc
# 18                                         wwwwwwwwwwc
# 19                                         wwwwwwwwwwc
# 20                                         wwwwwwwwwwc
# 21                                         wwwwwwwwwwc
# 22                                         wwwwwwwwwwc
# 23                                         wwwwwwwwwwc
# 24                                         wwwwwwwwwwc
# 25                                         wwwwwwwwwwc
# 26                                         wwwwwwwwwwc
# 27                                         wwwwwwwwwwc
# 28                                         wwwwwwwwwwc
# 29                                         wwwwwwwwwwc
# ..                                                 ...
# 130  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 131  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 132  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 133  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 134  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 135  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 136  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 137  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 138  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 139  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 140  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 141  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 142  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 143  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 144  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 145  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 146  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 147  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 148  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 149  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 150  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 151  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 152  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 153  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 154  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 155  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 156  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 157  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 158  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
# 159  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...
#
# [160 rows x 16 columns]

# %%
# compute interference of factors with each other
df = compute_interference_factor(df, 'A','B')
df = compute_interference_factor(df, 'A','C')
df = compute_interference_factor(df, 'B','C')
df = compute_interference_factor3(df, 'A', 'B','C')
df.to_csv(iotp_csv)
df.to_excel(iotp_excel)
df
# Out:
#      A  Average Aggregation Delay (ms)  IoT Device Battery (V)  \
# 0   -1                      162.719097                2.647007
# 1   -1                      166.100589                2.647212
# 2   -1                      166.828466                2.646607
# 3   -1                      166.507169                2.646602
# 4   -1                      166.800581                2.646603
# 5   -1                      159.470886                2.646607
# 6   -1                      170.661212                2.646202
# 7   -1                      166.530627                2.646807
# 8   -1                      166.962640                2.646402
# 9   -1                      169.669758                2.647612
# 10  -1                      169.414267                2.647007
# 11  -1                      165.206911                2.646807
# 12  -1                      170.687072                2.646807
# 13  -1                      168.785250                2.646807
# 14  -1                      168.917483                2.646602
# 15  -1                      169.713907                2.646402
# 16  -1                      170.121208                2.646603
# 17  -1                      167.037877                2.647412
# 18  -1                      169.570682                2.647012
# 19  -1                      169.469424                2.646602
# 20  -1                       88.167895                2.625920
# 21  -1                       87.749897                2.529557
# 22  -1                       91.035083                2.526378
#      Router Received Packet (pps)  Sampling Interval (s)  C  Throughput (B/s)  \
# 0                           238.4                     10 -1            2478.0
# 1                           238.4                     10 -1            2478.0
# 2                           238.4                     10 -1            2478.0
# 3                           238.4                     10 -1            2478.0
# 4                           238.4                     10 -1            2478.0
# 5                           238.4                     10 -1            2478.0
# 6                           238.4                     10 -1            2478.0
# 7                           238.4                     10 -1            2478.0
# 8                           238.4                     10 -1            2478.0
# 9                           238.4                     10 -1            2478.0
# 10                          238.4                     10 -1            2478.0
# 11                          238.4                     10 -1            2478.0
# 12                          238.4                     10 -1            2478.0
# 13                          238.4                     10 -1            2478.0
# 14                          238.4                     10 -1            2478.0
# 15                          238.4                     10 -1            2478.0
# 16                          238.4                     10 -1            2478.0
# 17                          238.4                     10 -1            2478.0
# 18                          238.4                     10 -1            2478.0
# 19                          238.4                     10 -1            2478.0
# 20                          278.8                     10  1            2904.8
# 21                          278.8                     10  1            2961.9
# 22                          278.8                     10  1            2950.1
# 23                          278.8                     10  1            2918.3
# 24                          278.8                     10  1            2934.0
# 25                          278.8                     10  1            2901.2
# 26                          278.8                     10  1            2926.9
# 27                          278.8                     10  1            2975.8
# 28                          278.8                     10  1            2921.2
# 29                          278.8                     10  1            2927.6
# ..                            ...                    ... ..               ...
# 130                         972.8                     10 -1            8160.0
# 131                         633.8                     10 -1            5312.5
# 132                         965.3                     10 -1            8117.5
# 133                         935.4                     10 -1            7862.5
# 134                        1104.0                     10 -1            9307.5
# 135                        1121.5                     10 -1            9435.0
# 136                         941.0                     10 -1            7947.5
# 137                         601.0                     10 -1            5015.0
# 138                        1026.8                     10 -1            8627.5
# 139                        1160.0                     10 -1            9775.0
# 140                         566.2                     10  1            4706.9
# 141                         945.4                     10  1            7953.3
# 142                         660.9                     10  1            5556.3
# 143                        1047.2                     10  1            8835.4
# 144                         815.7                     10  1            6871.9
# 145                        1006.6                     10  1            8627.1
# 146                        1079.4                     10  1            9160.6
# 147                         833.5                     10  1            7016.0
# 148                         922.1                     10  1            7899.4
# 149                         813.5                     10  1            6986.5
# 150                         663.5                     10  1            5582.8
# 151                         711.9                     10  1            5991.2
# 152                         874.2                     10  1            7374.4
# 153                         699.1                     10  1            5899.0
# 154                         967.5                     10  1            8165.8
# 155                        1076.7                     10  1            9243.0
# 156                         908.8                     10  1            7700.3
# 157                        1179.1                     10  1           10073.6
# 158                         976.2                     10  1            8249.9
# 159                        1026.4                     10  1            8694.3
#
#                                               Topology  AB  AC  BC  ABC
# 0                                          wwwwwwwwwwc   1   1   1   -1
# 1                                          wwwwwwwwwwc   1   1   1   -1
# 2                                          wwwwwwwwwwc   1   1   1   -1
# 3                                          wwwwwwwwwwc   1   1   1   -1
# 4                                          wwwwwwwwwwc   1   1   1   -1
# 5                                          wwwwwwwwwwc   1   1   1   -1
# 6                                          wwwwwwwwwwc   1   1   1   -1
# 7                                          wwwwwwwwwwc   1   1   1   -1
# 8                                          wwwwwwwwwwc   1   1   1   -1
# 9                                          wwwwwwwwwwc   1   1   1   -1
# 10                                         wwwwwwwwwwc   1   1   1   -1
# 11                                         wwwwwwwwwwc   1   1   1   -1
# 12                                         wwwwwwwwwwc   1   1   1   -1
# 13                                         wwwwwwwwwwc   1   1   1   -1
# 14                                         wwwwwwwwwwc   1   1   1   -1
# 15                                         wwwwwwwwwwc   1   1   1   -1
# 16                                         wwwwwwwwwwc   1   1   1   -1
# 17                                         wwwwwwwwwwc   1   1   1   -1
# 18                                         wwwwwwwwwwc   1   1   1   -1
# 19                                         wwwwwwwwwwc   1   1   1   -1
# 20                                         wwwwwwwwwwc   1  -1  -1    1
# 21                                         wwwwwwwwwwc   1  -1  -1    1
# 22                                         wwwwwwwwwwc   1  -1  -1    1
# 23                                         wwwwwwwwwwc   1  -1  -1    1
# 24                                         wwwwwwwwwwc   1  -1  -1    1
# 25                                         wwwwwwwwwwc   1  -1  -1    1
# 26                                         wwwwwwwwwwc   1  -1  -1    1
# 27                                         wwwwwwwwwwc   1  -1  -1    1
# 28                                         wwwwwwwwwwc   1  -1  -1    1
# 29                                         wwwwwwwwwwc   1  -1  -1    1
# ..                                                 ...  ..  ..  ..  ...
# 130  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 131  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 132  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 133  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 134  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 135  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 136  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 137  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 138  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 139  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1  -1  -1   -1
# 140  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 141  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 142  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 143  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 144  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 145  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 146  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 147  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 148  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 149  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 150  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 151  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 152  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 153  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 154  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 155  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 156  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 157  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 158  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
# 159  wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww...   1   1   1    1
#
# [160 rows x 20 columns]

# %%
# compute mean of the 2-k replicants
df_new = pd.DataFrame()
print 'LEVEL', '#TESTS'
for agg_lvl in df[ nm_map['aggregation_strategy'] ].unique():
    for dev_lvl in df[ nm_map['devices'] ].unique():        
        for sync_lvl in df[ nm_map['sync_flag'] ].unique():
            level = [[agg_lvl,dev_lvl,sync_lvl]]
            temp = df[ (df[nm_map['aggregation_strategy']] == agg_lvl) & (df[nm_map['devices']] == dev_lvl) & (df[nm_map['sync_flag']] == sync_lvl) ]
            print level, len(temp)
            temp = temp[measures_arr].mean(axis=0).to_frame().T
            temp = pd.concat([pd.DataFrame(data=level, columns=factors_arr), temp], axis=1)
            df_new = pd.concat([df_new, temp])
df_new
# Out:
# LEVEL #TESTS
# [[-1, -1, -1]] 20
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-39-9a583c6ea540> in <module>()
#       9             print level, len(temp)
#      10             temp = temp[measures_arr].mean(axis=0).to_frame().T
# ---> 11             temp = pd.concat([pd.DataFrame(data=level, columns=factors_arr), temp], axis=1)
#      12             df_new = pd.concat([df_new, temp])
#      13 df_new
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals/construction.pyc in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
#     403         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# --> 404                                dtype=dtype)
#     405     elif isinstance(data[0], compat.Mapping):
#     406         return _list_of_dict_to_arrays(data, columns,
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals/construction.pyc in _list_to_arrays(data, columns, coerce_float, dtype)
#     434         content = list(lib.to_object_array(data).T)
#     435     return _convert_object_array(content, columns, dtype=dtype,
# --> 436                                  coerce_float=coerce_float)
#     437
#     438
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals/construction.pyc in _convert_object_array(content, columns, coerce_float, dtype)
#     490             raise AssertionError('{col:d} columns passed, passed data had '
#     491                                  '{con} columns'.format(col=len(columns),
# --> 492                                                         con=len(content)))
#     493
#     494     # provide soft conversion of object dtypes
#
# AssertionError: 7 columns passed, passed data had 3 columns

# %%
# compute factor principal effects (qj) here 
df_quotients = []
for measure in measures_arr:
    row = []
    for factor in factors_arr:
        quot = (df_new[ factor ] * df_new[ measure ]).sum() / float(len(df_new))
        row.append(quot)
    df_quotients.append(row)
df_quotients = pd.DataFrame(data=df_quotients, columns=factors_arr)
df_quotients.set_axis(measures_arr, axis=0, inplace=True)
df_quotients

# %%
# calculate SS0 = sum(sum(Yij**2))
# (df[measures_arr]).T

# %%
# calculate variance per factor SSj = (2 ** k) * r * (q ** 2)
df_quotients = len(df_new) * len(df) * (df_quotients ** 2)
df_quotients

# %%
# df_quotients
# df_quotients.loc[ nm_map['avg_delay'] , : ].sort_values(ascending=False).index

# %%
y_label = "Factors Effect" if lang.upper() == 'EN' else 'Efeito dos Fatores'
x_label = 'Factors' if lang.upper() == 'EN' else 'Fatores'
show_pareto('full_fact_avg_delay', df_quotients.loc[ nm_map['avg_delay'] , : ], xlabel=x_label, ylabel=y_label)
show_pareto('full_fact_gt', df_quotients.loc[ nm_map['gt'] , : ], xlabel=x_label, ylabel=y_label)
show_pareto('full_fact_pktrecv', df_quotients.loc[ nm_map['pkt_recv'] , : ], xlabel=x_label, ylabel=y_label)
# if not barplot:
#     ax = show_lineplot(df_not_l2, 'goodput_iotp', x='pps_tcpreplay', y='goodput', category='aggregation_strategy')

# %%
# if barplot:
#     ax = show_barplot(df_l2_iotp10, 'pps_recv_l2_barplot', x='aggregation_strategy', y='pps_send', size=(4.5,7), scale_lim=[None, (1800,3000)])
# else:
#     ax = show_lineplot(df_l2_iotp10, 'pps_recv_l2_lineplot', x='pps_tcpreplay', y='pps_send', category='aggregation_strategy')

# %%
# if barplot:
#     ax = show_barplot(df_not_l2, 'pps_recv_iotp_barplot', x='aggregation_strategy', y='pps_send', size=(11,7), scale_lim=[None, (2750,3100)])
# else:
#     ax = show_lineplot(df_not_l2, 'pps_recv_iotp_lineplot', x='pps_tcpreplay', y='pps_send', category='aggregation_strategy')

# %%
# if barplot:
#     ax = show_barplot(df_l2_iotp10, 'pps_send_l2_barplot', x='aggregation_strategy', y='pps_recv', size=(4.5,7), scale_lim=[None, None])
# else:
#     ax = show_lineplot(df_l2_iotp10, 'pps_send_l2_lineplot', x='pps_tcpreplay', y='pps_recv', category='aggregation_strategy')

# %%
# if barplot:
#     ax = show_barplot(df_not_l2, 'pps_send_iotp_barplot', x='aggregation_strategy', y='pps_recv', size=(11,7), scale_lim=[None, (40,300)])
# else:
#     ax = show_lineplot(df_not_l2, 'pps_send_iotp_lineplot', x='pps_tcpreplay', y='pps_recv', category='aggregation_strategy')
